# %%
#pip install darts
#pip install alpha_vantage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
from darts import TimeSeries as DartsTimeSeries
from darts.datasets import AirPassengersDataset
key = open('API.txt').read()

# %%
ts = TimeSeries(key, output_format='pandas')
symbol = 'WTI' # Crude Oil Prices: West Texas Intermediate (WTI)
interval = '1min' 
data, meta = ts.get_intraday(symbol, interval, outputsize='full')

# %%
meta

data.info()

data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6636 entries, 2023-10-20 19:58:00 to 2023-09-29 07:11:00
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    6636 non-null   float64
#  1   2. high    6636 non-null   float64
#  2   3. low     6636 non-null   float64
#  3   4. close   6636 non-null   float64
#  4   5. volume  6636 non-null   float64
# dtypes: float64(5)
# memory usage: 311.1 KB
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2023-10-20 19:58:00     4.24     4.24    4.24      4.24        5.0
# 2023-10-20 19:28:00     4.15     4.15    4.15      4.15        1.0
# 2023-10-20 19:13:00     4.13     4.13    4.13      4.13        1.0
# 2023-10-20 19:00:00     4.15     4.15    4.15      4.15   132596.0
# 2023-10-20 18:59:00     4.14     4.14    4.14      4.14        1.0

# %%
plt.plot(data['4. close'])

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2023-10-20 19:58:00     4.24     4.24    4.24      4.24        5.0
# 2023-10-20 19:28:00     4.15     4.15    4.15      4.15        1.0
# 2023-10-20 19:13:00     4.13     4.13    4.13      4.13        1.0
# 2023-10-20 19:00:00     4.15     4.15    4.15      4.15   132596.0
# 2023-10-20 18:59:00     4.14     4.14    4.14      4.14        1.0
# ...                      ...      ...     ...       ...        ...
# 2023-09-29 08:08:00     4.45     4.45    4.45      4.45       10.0
# 2023-09-29 08:04:00     4.48     4.48    4.48      4.48      100.0
# 2023-09-29 08:01:00     4.48     4.48    4.48      4.48       20.0
# 2023-09-29 08:00:00     4.48     4.49    4.45      4.49     2051.0
# 2023-09-29 07:11:00     4.45     4.45    4.45      4.45       30.0
#
# [6636 rows x 5 columns]
