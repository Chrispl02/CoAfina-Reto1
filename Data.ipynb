# %%
#pip install darts
#pip install alpha_vantage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries
from darts import TimeSeries as DartsTimeSeries
from darts.datasets import AirPassengersDataset
key = open('API.txt').read()

# %%
ts = TimeSeries(key, output_format='pandas')
symbol = 'WTI' # Crude Oil Prices: West Texas Intermediate (WTI)
interval = '1day'  # Intervalo diario
start_date = '2006-01-01'
end_date = '2020-04-01'
data, meta = ts.get_daily(symbol, outputsize='full')
#data = data[(data.index >= start_date) & (data.index <= end_date)]

# %%
meta

data.info()

data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4715 entries, 2023-10-20 to 2005-01-28
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1. open    4715 non-null   float64
#  1   2. high    4715 non-null   float64
#  2   3. low     4715 non-null   float64
#  3   4. close   4715 non-null   float64
#  4   5. volume  4715 non-null   float64
# dtypes: float64(5)
# memory usage: 221.0 KB
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2023-10-20     4.20    4.245    4.12      4.15  1463052.0
# 2023-10-19     4.11    4.290    4.09      4.21  1990570.0
# 2023-10-18     4.20    4.260    4.14      4.24  2277971.0
# 2023-10-17     4.08    4.190    4.08      4.14  1667287.0
# 2023-10-16     4.13    4.145    4.05      4.12  1423191.0

# %%
plt.plot(data['4. close'])

# %%
data
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2023-10-20     4.20    4.245    4.12      4.15  1463052.0
# 2023-10-19     4.11    4.290    4.09      4.21  1990570.0
# 2023-10-18     4.20    4.260    4.14      4.24  2277971.0
# 2023-10-17     4.08    4.190    4.08      4.14  1667287.0
# 2023-10-16     4.13    4.145    4.05      4.12  1423191.0
# ...             ...      ...     ...       ...        ...
# 2005-02-03    18.25   18.350   18.23     18.25   303200.0
# 2005-02-02    18.25   18.400   18.19     18.21   265300.0
# 2005-02-01    18.20   18.400   18.08     18.21   656500.0
# 2005-01-31    18.50   18.590   17.50     18.20  1776800.0
# 2005-01-28    19.50   19.800   18.50     18.50  9813500.0
#
# [4715 rows x 5 columns]
